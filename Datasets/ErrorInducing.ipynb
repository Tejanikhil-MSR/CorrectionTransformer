# %%
import LookUpTable as lut
import pandas as pd
import re
import random
import Levenshtein

# %%
SamantarDatasetPath = r'./SamantarDatasetRaw.txt'
webscrapedDatasetPath = r'./web_scraped_data_raw.csv'

# %%
with open(SamantarDatasetPath, 'r', encoding='utf-8') as file:
    lines = [line.strip() for line in file.readlines()]

df = pd.DataFrame(lines, columns=["OriginalText"])

# %%
def clean_telugu_text(text):
    # Remove non-Telugu characters except whitespace
    cleaned = re.sub(r'[^\u0C00-\u0C7F\s]', '', text)
    # Replace multiple spaces with a single space
    cleaned = re.sub(r'\s+', ' ', cleaned)
    # Strip unnecessary leading/trailing whitespace
    cleaned = cleaned.strip()
    
    return cleaned

# %%
def get_levenstein(src, tar):
    return Levenshtein.distance(src, tar)

# %%
def substitute_consonants(text, error_percentage):
    characters = list(text)
    max_errors = int(len(characters) * error_percentage)
    error_count = 0
    tried_indices = set()
    
    start_length = len(characters)

    while error_count < max_errors and len(tried_indices) < len(characters):
        idx = random.randint(0, len(characters) - 1)
        if idx in tried_indices:
            continue
        tried_indices.add(idx)

        current_char = characters[idx]

        # Skip if character is not a consonant present the lookup table
        if current_char not in lut.SimpleCharacterReplacements.keys():
            continue

        # Skip if previous character is a virama (్)
        if (idx > 0 and characters[idx - 1] == '్') or (characters[idx]=="య" and idx < len(characters) - 1 and characters[idx + 1] == "ి"):
            continue

        # Get replacement options and choose one randomly
        replacements = lut.SimpleCharacterReplacements[current_char]
        replacement = random.choice(replacements)

        characters[idx] = replacement
        error_count += 1

    end_length = len(characters)

    print(f"Percentage of errors introduced: {round((error_count / start_length) * 100, 2)}% with number of deletions = {end_length-start_length}")
    avg_error = 0
    for (actual, error) in zip(text.split(" "), ''.join(characters).split(" ")):
        avg_error += get_levenstein(actual, error)
        
    AverageErrorPerWord = round(avg_error / len(text.split(" ")), 2)

    return ''.join(characters), AverageErrorPerWord

# %%
def substitute_stacked_diacritics(text, error_percentage):
    
    telugu_consonants = ['క', 'ఖ', 'గ', 'ఘ', 'ఙ','చ', 'ఛ', 'జ', 'ఝ', 'ఞ',
                         'ట', 'ఠ', 'డ', 'ఢ', 'ణ', 'త', 'థ', 'ద', 'ధ', 'న',
                        'ప', 'ఫ', 'బ', 'భ', 'మ', 'య', 'ర', 'ల', 'వ',
                        'శ', 'ష', 'స', 'హ', 'ళ', 'క్ష', 'ఱ']

    characters = list(text)
    max_errors = int(len(characters) * error_percentage)
    error_count = 0
    tried_indices = set()
    
    start_length = len(characters)

    while error_count < max_errors and len(tried_indices) < len(characters):
        idx = random.randint(0, len(characters) - 1)
        if idx in tried_indices:
            continue
        tried_indices.add(idx)

        current_char = characters[idx]

        # Skip if character is not a consonant present the lookup table
        if current_char not in lut.StackingReplacements.keys():
            continue

        # Skip if previous character is a virama (్)
        if (idx > 2 and characters[idx - 1] == '్' and characters[idx - 2] in telugu_consonants):
            # Get replacement options and choose one randomly
            replacements = lut.StackingReplacements[current_char]
            replacement = random.choice(replacements)

            characters[idx] = replacement
            error_count += 1

    end_length = len(characters)

    print(f"Percentage of errors introduced: {round((error_count / start_length) * 100, 2)}% with number of deletions = {end_length-start_length}")
    avg_error = 0
    for (actual, error) in zip(text.split(" "), ''.join(characters).split(" ")):
        avg_error += get_levenstein(actual, error)
        
    AverageErrorPerWord = round(avg_error / len(text.split(" ")), 2)

    return ''.join(characters), AverageErrorPerWord

# %%
df["OriginalText"] = df["OriginalText"].apply(clean_telugu_text)

# %%
# df[["15%_ErrorInducedText", "AverageErrorPerWord_15%"]] = df["OriginalText"].apply(lambda x: substitute_consonants(x, 0.15))
# df[["25%_ErrorInducedText", "AverageErrorPerWord_25%"]] = df["OriginalText"].apply(lambda x: substitute_consonants(x, 0.25))
# df[["35%_ErrorInducedText", "AverageErrorPerWord_35%"]] = df["OriginalText"].apply(lambda x: substitute_consonants(x, 0.35))
# df[["50%_ErrorInducedText", "AverageErrorPerWord_50%"]] = df["OriginalText"].apply(lambda x: substitute_consonants(x, 0.5))
# df.to_csv('./SamantarDatasetWithDirectConsonantSubstitutions.csv', index=False, encoding='utf-8-sig')

# %%
# df[["15%_ErrorInducedText", "AverageErrorPerWord_15%"]] = df["OriginalText"].apply(lambda x: substitute_stacked_diacritics(x, 0.15))
# df[["25%_ErrorInducedText", "AverageErrorPerWord_25%"]] = df["OriginalText"].apply(lambda x: substitute_stacked_diacritics(x, 0.25))
# df[["35%_Err[orInducedText", "AverageErrorPerWord_35%"]] = df["OriginalText"].apply(lambda x: substitute_stacked_diacritics(x, 0.35))
# df[["50%_ErrorInducedText", "AverageErrorPerWord_50%"]] = df["OriginalText"].apply(lambda x: substitute_stacked_diacritics(x, 0.5))
# df.to_csv('./SamantarDatasetWithDiacriticSubstitutions.csv', index=False, encoding='utf-8-sig')

# %%
# Model needs to learn from more context and accordingly correct the text
# substitute_stacked_diacritics("శంకరాచార్యులు అద్వైత సిద్ధాంతాన్ని ప్రవేశపెట్టారు", 0.15)
# Out:
# Percentage of errors introduced: 8.16% with number of deletions = 0
# 'శంకరాచార్వులు అద్యైత సిద్గాంతాన్వి ప్రవేశపెట్టారు'

# %% [markdown]
# ### Dealing with Web Scraped Dataset

# %%
scraped_df = pd.read_csv(webscrapedDatasetPath, encoding='utf-8-sig')

# %%
Q1 = scraped_df['word_count'].quantile(0.25)
Q3 = scraped_df['word_count'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = scraped_df[(scraped_df['word_count'] < lower_bound) | (scraped_df['word_count'] > upper_bound)]

print("Maximum word count in the dataset:", scraped_df['word_count'].max())
print("Min word count in the dataset:", scraped_df['word_count'].min())

print("Number of outliers:", len(outliers))
# Out:
# Maximum word count in the dataset: 500
# Min word count in the dataset: 13
# Number of outliers: 0

# %%
# since there are no outliers, split each sentence into 3 sentences of length total number of words/3 = 500/3 ~ 160
max_sentence_length = 100 # max number of words in a sentence
split_sentences_list = []
for index, row in scraped_df.iterrows():
    text = row['content']
    words = text.split()
    for i in range(0, len(words), max_sentence_length):
        new_sentence = ' '.join(words[i:i + max_sentence_length])
        split_sentences_list.append(new_sentence)

# remove the empty strings from the list
split_sentences_list = [sentence for sentence in split_sentences_list if sentence.strip() != '']

# filter out the sentence with sentence length < 20 words
split_sentences_list = [sentence for sentence in split_sentences_list if len(sentence.split()) >= 20]

# %%
print("Number of sentences after splitting:", len(split_sentences_list))
print("Max sentence length after splitting:", max([len(sentence.split()) for sentence in split_sentences_list]))
print("Min sentence length after splitting:", min([len(sentence.split()) for sentence in split_sentences_list]))
print("Average sentence length after splitting:", sum([len(sentence.split()) for sentence in split_sentences_list]) / len(split_sentences_list))
# Out:
# Number of sentences after splitting: 3240
# Max sentence length after splitting: 100
# Min sentence length after splitting: 20
# Average sentence length after splitting: 89.22901234567901

# %%
scraped_data_df = pd.DataFrame(split_sentences_list, columns=["OriginalText"])
scraped_data_df["OriginalText"] = scraped_data_df["OriginalText"].apply(clean_telugu_text)

# %%
# scraped_data_df[["15%_ErrorInducedText", "AverageErrorPerWord_15%"]] = scraped_data_df["OriginalText"].apply(lambda x: substitute_consonants(x, 0.15)).tolist()
# scraped_data_df[["25%_ErrorInducedText", "AverageErrorPerWord_25%"]] = scraped_data_df["OriginalText"].apply(lambda x: substitute_consonants(x, 0.25)).tolist()
# scraped_data_df[["35%_ErrorInducedText", "AverageErrorPerWord_35%"]] = scraped_data_df["OriginalText"].apply(lambda x: substitute_consonants(x, 0.35)).tolist()
# scraped_data_df[["50%_ErrorInducedText", "AverageErrorPerWord_50%"]] = scraped_data_df["OriginalText"].apply(lambda x: substitute_consonants(x, 0.5)).tolist()
# scraped_data_df.to_csv('./WebScrapedDatasetWithDirectConsonantSubstitutions.csv', index=False, encoding='utf-8-sig')

# %%
scraped_data_df[["15%_ErrorInducedText", "AverageErrorPerWord_15%"]] = scraped_data_df["OriginalText"].apply(lambda x: substitute_stacked_diacritics(x, 0.15)).tolist()
scraped_data_df[["25%_ErrorInducedText", "AverageErrorPerWord_25%"]] = scraped_data_df["OriginalText"].apply(lambda x: substitute_stacked_diacritics(x, 0.25)).tolist()
scraped_data_df[["35%_ErrorInducedText", "AverageErrorPerWord_35%"]] = scraped_data_df["OriginalText"].apply(lambda x: substitute_stacked_diacritics(x, 0.35)).tolist()
scraped_data_df[["50%_ErrorInducedText", "AverageErrorPerWord_50%"]] = scraped_data_df["OriginalText"].apply(lambda x: substitute_stacked_diacritics(x, 0.5)).tolist()
scraped_data_df.to_csv('./WebScrapedDatasetWithDiacriticSubstitutions.csv', index=False, encoding='utf-8-sig')
# Out:
# Percentage of errors introduced: 2.77% with number of deletions = 0
# Percentage of errors introduced: 4.52% with number of deletions = 0
# Percentage of errors introduced: 3.82% with number of deletions = 0
# Percentage of errors introduced: 5.21% with number of deletions = 0
# Percentage of errors introduced: 3.2% with number of deletions = 0
# Percentage of errors introduced: 2.05% with number of deletions = 0
# Percentage of errors introduced: 5.19% with number of deletions = 0
# Percentage of errors introduced: 2.8% with number of deletions = 0
# Percentage of errors introduced: 4.41% with number of deletions = 0
# Percentage of errors introduced: 2.96% with number of deletions = 0
# Percentage of errors introduced: 2.82% with number of deletions = 0
# Percentage of errors introduced: 6.29% with number of deletions = 0
# Percentage of errors introduced: 2.96% with number of deletions = 0
# Percentage of errors introduced: 2.82% with number of deletions = 0
# Percentage of errors introduced: 6.29% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 3.6% with number of deletions = 0
# Percentage of errors introduced: 3.75% with number of deletions = 0
# Percentage of errors introduced: 3.31% with number of deletions = 0
# Percentage of errors introduced: 4.84% with number of deletions = 0
# Percentage of errors introduced: 4.21% with number of deletions = 0
# Percentage of errors introduced: 3.69% with number of deletions = 0
# Percentage of errors introduced: 2.88% with number of deletions = 0
# Percentage of errors introduced: 4.58% with number of deletions = 0
# Percentage of errors introduced: 3.24% with number of deletions = 0
# Percentage of errors introduced: 3.57% with number of deletions = 0
# Percentage of errors introduced: 4.25% with number of deletions = 0
# Percentage of errors introduced: 3.51% with number of deletions = 0
# Percentage of errors introduced: 3.72% with number of deletions = 0
# Percentage of errors introduced: 6.26% with number of deletions = 0
# Percentage of errors introduced: 4.09% with number of deletions = 0
# Percentage of errors introduced: 5.42% with number of deletions = 0
# Percentage of errors introduced: 3.12% with number of deletions = 0
# Percentage of errors introduced: 5.24% with number of deletions = 0
# Percentage of errors introduced: 4.72% with number of deletions = 0
# Percentage of errors introduced: 2.51% with number of deletions = 0
# Percentage of errors introduced: 3.44% with number of deletions = 0
# Percentage of errors introduced: 5.2% with number of deletions = 0
# Percentage of errors introduced: 4.88% with number of deletions = 0
# Percentage of errors introduced: 3.58% with number of deletions = 0
# Percentage of errors introduced: 3.79% with number of deletions = 0
# Percentage of errors introduced: 3.86% with number of deletions = 0
# Percentage of errors introduced: 3.27% with number of deletions = 0
# Percentage of errors introduced: 4.57% with number of deletions = 0
# Percentage of errors introduced: 3.88% with number of deletions = 0
# Percentage of errors introduced: 3.22% with number of deletions = 0
# Percentage of errors introduced: 3.66% with number of deletions = 0
# Percentage of errors introduced: 3.79% with number of deletions = 0
# Percentage of errors introduced: 3.44% with number of deletions = 0
# Percentage of errors introduced: 3.93% with number of deletions = 0
# Percentage of errors introduced: 4.13% with number of deletions = 0
# Percentage of errors introduced: 4.76% with number of deletions = 0
# Percentage of errors introduced: 3.78% with number of deletions = 0
# Percentage of errors introduced: 4.29% with number of deletions = 0
# Percentage of errors introduced: 5.98% with number of deletions = 0
# Percentage of errors introduced: 4.41% with number of deletions = 0
# Percentage of errors introduced: 5.22% with number of deletions = 0
# Percentage of errors introduced: 4.31% with number of deletions = 0
# Percentage of errors introduced: 4.79% with number of deletions = 0
# Percentage of errors introduced: 6.44% with number of deletions = 0
# Percentage of errors introduced: 5.9% with number of deletions = 0
# Percentage of errors introduced: 6.63% with number of deletions = 0
# Percentage of errors introduced: 4.13% with number of deletions = 0
# Percentage of errors introduced: 4.67% with number of deletions = 0
# Percentage of errors introduced: 4.27% with number of deletions = 0
# Percentage of errors introduced: 3.9% with number of deletions = 0
# Percentage of errors introduced: 5.18% with number of deletions = 0
# Percentage of errors introduced: 5.04% with number of deletions = 0
# Percentage of errors introduced: 3.26% with number of deletions = 0
# Percentage of errors introduced: 5.43% with number of deletions = 0
# Percentage of errors introduced: 5.27% with number of deletions = 0
# Percentage of errors introduced: 4.79% with number of deletions = 0
# Percentage of errors introduced: 5.04% with number of deletions = 0
# Percentage of errors introduced: 3.26% with number of deletions = 0
# Percentage of errors introduced: 5.43% with number of deletions = 0
# Percentage of errors introduced: 5.27% with number of deletions = 0
# Percentage of errors introduced: 4.79% with number of deletions = 0
# Percentage of errors introduced: 4.57% with number of deletions = 0
# Percentage of errors introduced: 3.93% with number of deletions = 0
# Percentage of errors introduced: 4.23% with number of deletions = 0
# Percentage of errors introduced: 3.4% with number of deletions = 0
# Percentage of errors introduced: 3.83% with number of deletions = 0
# Percentage of errors introduced: 4.61% with number of deletions = 0
# Percentage of errors introduced: 3.83% with number of deletions = 0
# Percentage of errors introduced: 2.64% with number of deletions = 0
# Percentage of errors introduced: 3.68% with number of deletions = 0
# Percentage of errors introduced: 5.26% with number of deletions = 0
# Percentage of errors introduced: 5.54% with number of deletions = 0
# Percentage of errors introduced: 4.66% with number of deletions = 0
# Percentage of errors introduced: 4.27% with number of deletions = 0
# Percentage of errors introduced: 4.8% with number of deletions = 0
# Percentage of errors introduced: 5.71% with number of deletions = 0
# Percentage of errors introduced: 4.61% with number of deletions = 0
# Percentage of errors introduced: 4.08% with number of deletions = 0
# Percentage of errors introduced: 3.42% with number of deletions = 0
# Percentage of errors introduced: 4.55% with number of deletions = 0
# Percentage of errors introduced: 2.62% with number of deletions = 0
# Percentage of errors introduced: 4.14% with number of deletions = 0
# Percentage of errors introduced: 4.14% with number of deletions = 0
# Percentage of errors introduced: 4.84% with number of deletions = 0
# Percentage of errors introduced: 5.38% with number of deletions = 0
# Percentage of errors introduced: 2.81% with number of deletions = 0
# Percentage of errors introduced: 3.26% with number of deletions = 0
# Percentage of errors introduced: 2.96% with number of deletions = 0
# Percentage of errors introduced: 3.46% with number of deletions = 0
# Percentage of errors introduced: 4.19% with number of deletions = 0
# Percentage of errors introduced: 3.99% with number of deletions = 0
# Percentage of errors introduced: 5.1% with number of deletions = 0
# Percentage of errors introduced: 4.06% with number of deletions = 0
# Percentage of errors introduced: 5.08% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 4.19% with number of deletions = 0
# Percentage of errors introduced: 3.29% with number of deletions = 0
# Percentage of errors introduced: 4.07% with number of deletions = 0
# Percentage of errors introduced: 2.9% with number of deletions = 0
# Percentage of errors introduced: 5.24% with number of deletions = 0
# Percentage of errors introduced: 4.86% with number of deletions = 0
# Percentage of errors introduced: 5.89% with number of deletions = 0
# Percentage of errors introduced: 5.1% with number of deletions = 0
# Percentage of errors introduced: 4.12% with number of deletions = 0
# Percentage of errors introduced: 4.72% with number of deletions = 0
# Percentage of errors introduced: 3.95% with number of deletions = 0
# Percentage of errors introduced: 5.09% with number of deletions = 0
# Percentage of errors introduced: 4.35% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 5.53% with number of deletions = 0
# Percentage of errors introduced: 3.25% with number of deletions = 0
# Percentage of errors introduced: 4.74% with number of deletions = 0
# Percentage of errors introduced: 5.03% with number of deletions = 0
# Percentage of errors introduced: 3.83% with number of deletions = 0
# Percentage of errors introduced: 5.78% with number of deletions = 0
# Percentage of errors introduced: 5.47% with number of deletions = 0
# Percentage of errors introduced: 5.54% with number of deletions = 0
# Percentage of errors introduced: 4.93% with number of deletions = 0
# Percentage of errors introduced: 5.64% with number of deletions = 0
# Percentage of errors introduced: 5.02% with number of deletions = 0
# Percentage of errors introduced: 4.73% with number of deletions = 0
# Percentage of errors introduced: 4.32% with number of deletions = 0
# Percentage of errors introduced: 4.37% with number of deletions = 0
# Percentage of errors introduced: 3.93% with number of deletions = 0
# Percentage of errors introduced: 5.48% with number of deletions = 0
# Percentage of errors introduced: 4.92% with number of deletions = 0
# Percentage of errors introduced: 5.78% with number of deletions = 0
# Percentage of errors introduced: 4.59% with number of deletions = 0
# Percentage of errors introduced: 5.05% with number of deletions = 0
# Percentage of errors introduced: 3.06% with number of deletions = 0
# Percentage of errors introduced: 3.76% with number of deletions = 0
# Percentage of errors introduced: 3.17% with number of deletions = 0
# Percentage of errors introduced: 4.22% with number of deletions = 0
# Percentage of errors introduced: 5.5% with number of deletions = 0
# Percentage of errors introduced: 5.06% with number of deletions = 0
# Percentage of errors introduced: 3.12% with number of deletions = 0
# Percentage of errors introduced: 3.53% with number of deletions = 0
# Percentage of errors introduced: 3.73% with number of deletions = 0
# Percentage of errors introduced: 3.09% with number of deletions = 0
# Percentage of errors introduced: 3.91% with number of deletions = 0
# Percentage of errors introduced: 3.75% with number of deletions = 0
# Percentage of errors introduced: 3.52% with number of deletions = 0
# Percentage of errors introduced: 4.49% with number of deletions = 0
# Percentage of errors introduced: 3.84% with number of deletions = 0
# Percentage of errors introduced: 5.03% with number of deletions = 0
# Percentage of errors introduced: 3.4% with number of deletions = 0
# Percentage of errors introduced: 4.82% with number of deletions = 0
# Percentage of errors introduced: 2.56% with number of deletions = 0
# Percentage of errors introduced: 3.05% with number of deletions = 0
# Percentage of errors introduced: 3.91% with number of deletions = 0
# Percentage of errors introduced: 2.61% with number of deletions = 0
# Percentage of errors introduced: 4.12% with number of deletions = 0
# Percentage of errors introduced: 3.43% with number of deletions = 0
# Percentage of errors introduced: 5.31% with number of deletions = 0
# Percentage of errors introduced: 4.62% with number of deletions = 0
# Percentage of errors introduced: 4.24% with number of deletions = 0
# Percentage of errors introduced: 4.05% with number of deletions = 0
# Percentage of errors introduced: 4.53% with number of deletions = 0
# Percentage of errors introduced: 4.03% with number of deletions = 0
# Percentage of errors introduced: 5.09% with number of deletions = 0
# Percentage of errors introduced: 4.23% with number of deletions = 0
# Percentage of errors introduced: 4.89% with number of deletions = 0
# Percentage of errors introduced: 4.79% with number of deletions = 0
# Percentage of errors introduced: 5.72% with number of deletions = 0
# Percentage of errors introduced: 2.84% with number of deletions = 0
# Percentage of errors introduced: 3.35% with number of deletions = 0
# Percentage of errors introduced: 4.96% with number of deletions = 0
# Percentage of errors introduced: 4.56% with number of deletions = 0
# Percentage of errors introduced: 5.82% with number of deletions = 0
# Percentage of errors introduced: 2.37% with number of deletions = 0
# Percentage of errors introduced: 4.36% with number of deletions = 0
# Percentage of errors introduced: 3.55% with number of deletions = 0
# Percentage of errors introduced: 3.92% with number of deletions = 0
# Percentage of errors introduced: 2.71% with number of deletions = 0
# Percentage of errors introduced: 4.03% with number of deletions = 0
# Percentage of errors introduced: 3.47% with number of deletions = 0
# Percentage of errors introduced: 2.91% with number of deletions = 0
# Percentage of errors introduced: 4.72% with number of deletions = 0
# Percentage of errors introduced: 3.85% with number of deletions = 0
# Percentage of errors introduced: 0.54% with number of deletions = 0
# Percentage of errors introduced: 3.53% with number of deletions = 0
# Percentage of errors introduced: 5.22% with number of deletions = 0
# Percentage of errors introduced: 1.96% with number of deletions = 0
# Percentage of errors introduced: 3.49% with number of deletions = 0
# Percentage of errors introduced: 3.47% with number of deletions = 0
# Percentage of errors introduced: 6.16% with number of deletions = 0
# Percentage of errors introduced: 3.35% with number of deletions = 0
# Percentage of errors introduced: 3.39% with number of deletions = 0
# Percentage of errors introduced: 3.97% with number of deletions = 0
# Percentage of errors introduced: 4.23% with number of deletions = 0
# Percentage of errors introduced: 0.73% with number of deletions = 0
# Percentage of errors introduced: 4.47% with number of deletions = 0
# Percentage of errors introduced: 3.77% with number of deletions = 0
# Percentage of errors introduced: 4.72% with number of deletions = 0
# Percentage of errors introduced: 4.76% with number of deletions = 0
# Percentage of errors introduced: 3.53% with number of deletions = 0
# Percentage of errors introduced: 4.8% with number of deletions = 0
# Percentage of errors introduced: 4.43% with number of deletions = 0
# Percentage of errors introduced: 4.0% with number of deletions = 0
# Percentage of errors introduced: 4.89% with number of deletions = 0
# Percentage of errors introduced: 3.06% with number of deletions = 0
# Percentage of errors introduced: 2.84% with number of deletions = 0
# Percentage of errors introduced: 2.3% with number of deletions = 0
# Percentage of errors introduced: 4.03% with number of deletions = 0
# Percentage of errors introduced: 3.54% with number of deletions = 0
# Percentage of errors introduced: 3.05% with number of deletions = 0
# Percentage of errors introduced: 4.75% with number of deletions = 0
# Percentage of errors introduced: 3.69% with number of deletions = 0
# Percentage of errors introduced: 3.84% with number of deletions = 0
# Percentage of errors introduced: 2.97% with number of deletions = 0
# Percentage of errors introduced: 3.74% with number of deletions = 0
# Percentage of errors introduced: 1.89% with number of deletions = 0
# Percentage of errors introduced: 4.22% with number of deletions = 0
# Percentage of errors introduced: 3.72% with number of deletions = 0
# Percentage of errors introduced: 5.47% with number of deletions = 0
# Percentage of errors introduced: 2.89% with number of deletions = 0
# Percentage of errors introduced: 3.9% with number of deletions = 0
# Percentage of errors introduced: 4.33% with number of deletions = 0
# Percentage of errors introduced: 4.95% with number of deletions = 0
# Percentage of errors introduced: 2.58% with number of deletions = 0
# Percentage of errors introduced: 3.18% with number of deletions = 0
# Percentage of errors introduced: 4.59% with number of deletions = 0
# Percentage of errors introduced: 3.15% with number of deletions = 0
# Percentage of errors introduced: 4.52% with number of deletions = 0
# Percentage of errors introduced: 4.6% with number of deletions = 0
# Percentage of errors introduced: 5.13% with number of deletions = 0
# Percentage of errors introduced: 4.92% with number of deletions = 0
# Percentage of errors introduced: 5.6% with number of deletions = 0
# Percentage of errors introduced: 3.5% with number of deletions = 0
# Percentage of errors introduced: 5.17% with number of deletions = 0
# Percentage of errors introduced: 3.59% with number of deletions = 0
# Percentage of errors introduced: 3.76% with number of deletions = 0
# Percentage of errors introduced: 3.17% with number of deletions = 0
# Percentage of errors introduced: 4.01% with number of deletions = 0
# Percentage of errors introduced: 3.93% with number of deletions = 0
# Percentage of errors introduced: 3.53% with number of deletions = 0
# Percentage of errors introduced: 2.64% with number of deletions = 0
# Percentage of errors introduced: 3.13% with number of deletions = 0
# Percentage of errors introduced: 5.95% with number of deletions = 0
# Percentage of errors introduced: 4.39% with number of deletions = 0
# Percentage of errors introduced: 5.38% with number of deletions = 0
# Percentage of errors introduced: 6.07% with number of deletions = 0
# Percentage of errors introduced: 6.52% with number of deletions = 0
# Percentage of errors introduced: 3.35% with number of deletions = 0
# Percentage of errors introduced: 3.84% with number of deletions = 0
# Percentage of errors introduced: 3.13% with number of deletions = 0
# Percentage of errors introduced: 3.65% with number of deletions = 0
# Percentage of errors introduced: 2.99% with number of deletions = 0
# Percentage of errors introduced: 3.15% with number of deletions = 0
# Percentage of errors introduced: 3.9% with number of deletions = 0
# Percentage of errors introduced: 5.24% with number of deletions = 0
# Percentage of errors introduced: 4.33% with number of deletions = 0
# Percentage of errors introduced: 5.48% with number of deletions = 0
# Percentage of errors introduced: 2.77% with number of deletions = 0
# Percentage of errors introduced: 3.08% with number of deletions = 0
# Percentage of errors introduced: 3.49% with number of deletions = 0
# Percentage of errors introduced: 3.67% with number of deletions = 0
# Percentage of errors introduced: 5.7% with number of deletions = 0
# Percentage of errors introduced: 3.8% with number of deletions = 0
# Percentage of errors introduced: 1.1% with number of deletions = 0
# Percentage of errors introduced: 4.91% with number of deletions = 0
# Percentage of errors introduced: 3.79% with number of deletions = 0
# Percentage of errors introduced: 5.03% with number of deletions = 0
# Percentage of errors introduced: 5.12% with number of deletions = 0
# Percentage of errors introduced: 3.81% with number of deletions = 0
# Percentage of errors introduced: 4.11% with number of deletions = 0
# Percentage of errors introduced: 4.12% with number of deletions = 0
# Percentage of errors introduced: 4.15% with number of deletions = 0
# Percentage of errors introduced: 4.72% with number of deletions = 0
# Percentage of errors introduced: 4.52% with number of deletions = 0
# Percentage of errors introduced: 4.34% with number of deletions = 0
# Percentage of errors introduced: 4.1% with number of deletions = 0
# Percentage of errors introduced: 3.31% with number of deletions = 0
# Percentage of errors introduced: 4.36% with number of deletions = 0
# Percentage of errors introduced: 3.66% with number of deletions = 0
# Percentage of errors introduced: 2.84% with number of deletions = 0
# Percentage of errors introduced: 3.7% with number of deletions = 0
# Percentage of errors introduced: 5.49% with number of deletions = 0
# Percentage of errors introduced: 3.96% with number of deletions = 0
# Percentage of errors introduced: 6.01% with number of deletions = 0
# Percentage of errors introduced: 5.22% with number of deletions = 0
# Percentage of errors introduced: 4.71% with number of deletions = 0
# Percentage of errors introduced: 3.15% with number of deletions = 0
# Percentage of errors introduced: 4.98% with number of deletions = 0
# Percentage of errors introduced: 7.66% with number of deletions = 0
# Percentage of errors introduced: 5.19% with number of deletions = 0
# Percentage of errors introduced: 2.41% with number of deletions = 0
# Percentage of errors introduced: 3.68% with number of deletions = 0
# Percentage of errors introduced: 4.42% with number of deletions = 0
# Percentage of errors introduced: 2.97% with number of deletions = 0
# Percentage of errors introduced: 3.96% with number of deletions = 0
# Percentage of errors introduced: 3.59% with number of deletions = 0
# Percentage of errors introduced: 3.57% with number of deletions = 0
# Percentage of errors introduced: 3.46% with number of deletions = 0
# Percentage of errors introduced: 2.92% with number of deletions = 0
# Percentage of errors introduced: 5.03% with number of deletions = 0
# Percentage of errors introduced: 2.5% with number of deletions = 0
# Percentage of errors introduced: 5.82% with number of deletions = 0
# Percentage of errors introduced: 7.03% with number of deletions = 0
# Percentage of errors introduced: 7.02% with number of deletions = 0
# Percentage of errors introduced: 6.56% with number of deletions = 0
# Percentage of errors introduced: 6.9% with number of deletions = 0
# Percentage of errors introduced: 4.26% with number of deletions = 0
# Percentage of errors introduced: 8.38% with number of deletions = 0
# Percentage of errors introduced: 3.78% with number of deletions = 0
# Percentage of errors introduced: 4.2% with number of deletions = 0
# Percentage of errors introduced: 4.51% with number of deletions = 0
# Percentage of errors introduced: 4.51% with number of deletions = 0
# Percentage of errors introduced: 5.38% with number of deletions = 0
# Percentage of errors introduced: 4.59% with number of deletions = 0
# Percentage of errors introduced: 5.04% with number of deletions = 0
# Percentage of errors introduced: 4.62% with number of deletions = 0
# Percentage of errors introduced: 2.39% with number of deletions = 0
# Percentage of errors introduced: 4.94% with number of deletions = 0
# Percentage of errors introduced: 3.43% with number of deletions = 0
# Percentage of errors introduced: 3.96% with number of deletions = 0
# Percentage of errors introduced: 5.48% with number of deletions = 0
# Percentage of errors introduced: 5.82% with number of deletions = 0
# Percentage of errors introduced: 4.06% with number of deletions = 0
# Percentage of errors introduced: 3.36% with number of deletions = 0
# Percentage of errors introduced: 3.07% with number of deletions = 0
# Percentage of errors introduced: 4.07% with number of deletions = 0
# Percentage of errors introduced: 4.5% with number of deletions = 0
# Percentage of errors introduced: 4.17% with number of deletions = 0
# Percentage of errors introduced: 5.17% with number of deletions = 0
# Percentage of errors introduced: 4.75% with number of deletions = 0
# Percentage of errors introduced: 3.44% with number of deletions = 0
# Percentage of errors introduced: 3.66% with number of deletions = 0
# Percentage of errors introduced: 4.32% with number of deletions = 0
# Percentage of errors introduced: 4.45% with number of deletions = 0
# Percentage of errors introduced: 4.88% with number of deletions = 0
# Percentage of errors introduced: 4.34% with number of deletions = 0
# Percentage of errors introduced: 4.2% with number of deletions = 0
# Percentage of errors introduced: 4.01% with number of deletions = 0
# Percentage of errors introduced: 5.35% with number of deletions = 0
# Percentage of errors introduced: 5.12% with number of deletions = 0
# Percentage of errors introduced: 4.72% with number of deletions = 0
# Percentage of errors introduced: 3.55% with number of deletions = 0
# Percentage of errors introduced: 4.43% with number of deletions = 0
# Percentage of errors introduced: 4.27% with number of deletions = 0
# Percentage of errors introduced: 4.26% with number of deletions = 0
# Percentage of errors introduced: 2.07% with number of deletions = 0
# Percentage of errors introduced: 3.99% with number of deletions = 0
# Percentage of errors introduced: 2.82% with number of deletions = 0
# Percentage of errors introduced: 4.59% with number of deletions = 0
# Percentage of errors introduced: 4.17% with number of deletions = 0
# Percentage of errors introduced: 2.6% with number of deletions = 0
# Percentage of errors introduced: 3.88% with number of deletions = 0
# Percentage of errors introduced: 3.77% with number of deletions = 0
# Percentage of errors introduced: 1.84% with number of deletions = 0
# Percentage of errors introduced: 4.52% with number of deletions = 0
# Percentage of errors introduced: 4.1% with number of deletions = 0
# Percentage of errors introduced: 4.39% with number of deletions = 0
# Percentage of errors introduced: 3.63% with number of deletions = 0
# Percentage of errors introduced: 4.3% with number of deletions = 0
# Percentage of errors introduced: 3.1% with number of deletions = 0
# Percentage of errors introduced: 5.0% with number of deletions = 0
# Percentage of errors introduced: 0.56% with number of deletions = 0
# Percentage of errors introduced: 3.6% with number of deletions = 0
# Percentage of errors introduced: 3.53% with number of deletions = 0
# Percentage of errors introduced: 3.64% with number of deletions = 0
# Percentage of errors introduced: 4.1% with number of deletions = 0
# Percentage of errors introduced: 4.33% with number of deletions = 0
# Percentage of errors introduced: 4.73% with number of deletions = 0
# Percentage of errors introduced: 4.32% with number of deletions = 0
# Percentage of errors introduced: 3.67% with number of deletions = 0
# Percentage of errors introduced: 3.85% with number of deletions = 0
# Percentage of errors introduced: 4.36% with number of deletions = 0
# Percentage of errors introduced: 5.2% with number of deletions = 0
# Percentage of errors introduced: 3.96% with number of deletions = 0
# Percentage of errors introduced: 4.57% with number of deletions = 0
# Percentage of errors introduced: 4.86% with number of deletions = 0
# Percentage of errors introduced: 3.0% with number of deletions = 0
# Percentage of errors introduced: 5.63% with number of deletions = 0
# Percentage of errors introduced: 3.24% with number of deletions = 0
# Percentage of errors introduced: 5.27% with number of deletions = 0
# Percentage of errors introduced: 3.48% with number of deletions = 0
# Percentage of errors introduced: 3.66% with number of deletions = 0
# Percentage of errors introduced: 3.23% with number of deletions = 0
# Percentage of errors introduced: 3.29% with number of deletions = 0
# Percentage of errors introduced: 4.07% with number of deletions = 0
# Percentage of errors introduced: 4.89% with number of deletions = 0
# Percentage of errors introduced: 3.83% with number of deletions = 0
# Percentage of errors introduced: 4.1% with number of deletions = 0
# Percentage of errors introduced: 2.89% with number of deletions = 0
# Percentage of errors introduced: 3.46% with number of deletions = 0
# Percentage of errors introduced: 5.08% with number of deletions = 0
# Percentage of errors introduced: 2.78% with number of deletions = 0
# Percentage of errors introduced: 4.5% with number of deletions = 0
# Percentage of errors introduced: 4.35% with number of deletions = 0
# Percentage of errors introduced: 5.71% with number of deletions = 0
# Percentage of errors introduced: 5.41% with number of deletions = 0
# Percentage of errors introduced: 4.77% with number of deletions = 0
# Percentage of errors introduced: 6.82% with number of deletions = 0
# Percentage of errors introduced: 5.54% with number of deletions = 0
# Percentage of errors introduced: 5.31% with number of deletions = 0
# Percentage of errors introduced: 4.9% with number of deletions = 0
# Percentage of errors introduced: 3.21% with number of deletions = 0
# Percentage of errors introduced: 3.46% with number of deletions = 0
# Percentage of errors introduced: 3.74% with number of deletions = 0
# Percentage of errors introduced: 4.45% with number of deletions = 0
# Percentage of errors introduced: 4.44% with number of deletions = 0
# Percentage of errors introduced: 5.88% with number of deletions = 0
# Percentage of errors introduced: 4.8% with number of deletions = 0
# Percentage of errors introduced: 3.86% with number of deletions = 0
# Percentage of errors introduced: 5.25% with number of deletions = 0
# Percentage of errors introduced: 4.03% with number of deletions = 0
# Percentage of errors introduced: 2.1% with number of deletions = 0
# Percentage of errors introduced: 2.99% with number of deletions = 0
# Percentage of errors introduced: 2.59% with number of deletions = 0
# Percentage of errors introduced: 2.67% with number of deletions = 0
# Percentage of errors introduced: 5.64% with number of deletions = 0
# Percentage of errors introduced: 5.97% with number of deletions = 0
# Percentage of errors introduced: 2.74% with number of deletions = 0
# Percentage of errors introduced: 3.55% with number of deletions = 0
# Percentage of errors introduced: 5.64% with number of deletions = 0
# Percentage of errors introduced: 5.59% with number of deletions = 0
# Percentage of errors introduced: 3.49% with number of deletions = 0
# Percentage of errors introduced: 3.77% with number of deletions = 0
# Percentage of errors introduced: 3.09% with number of deletions = 0
# Percentage of errors introduced: 3.97% with number of deletions = 0
# Percentage of errors introduced: 4.16% with number of deletions = 0
# Percentage of errors introduced: 5.2% with number of deletions = 0
# Percentage of errors introduced: 4.29% with number of deletions = 0
# Percentage of errors introduced: 3.75% with number of deletions = 0
# Percentage of errors introduced: 3.28% with number of deletions = 0
# Percentage of errors introduced: 2.85% with number of deletions = 0
# Percentage of errors introduced: 2.49% with number of deletions = 0
# Percentage of errors introduced: 1.86% with number of deletions = 0
# Percentage of errors introduced: 5.71% with number of deletions = 0
# Percentage of errors introduced: 4.36% with number of deletions = 0
# Percentage of errors introduced: 5.11% with number of deletions = 0
# Percentage of errors introduced: 4.69% with number of deletions = 0
# Percentage of errors introduced: 4.89% with number of deletions = 0
# Percentage of errors introduced: 5.64% with number of deletions = 0
# Percentage of errors introduced: 5.64% with number of deletions = 0
# Percentage of errors introduced: 4.69% with number of deletions = 0
# Percentage of errors introduced: 4.32% with number of deletions = 0
# Percentage of errors introduced: 3.72% with number of deletions = 0
# Percentage of errors introduced: 5.33% with number of deletions = 0
# Percentage of errors introduced: 3.93% with number of deletions = 0
# Percentage of errors introduced: 3.92% with number of deletions = 0
# Percentage of errors introduced: 4.56% with number of deletions = 0
# Percentage of errors introduced: 5.16% with number of deletions = 0
# Percentage of errors introduced: 3.01% with number of deletions = 0
# Percentage of errors introduced: 3.73% with number of deletions = 0
# Percentage of errors introduced: 4.12% with number of deletions = 0
# Percentage of errors introduced: 4.43% with number of deletions = 0
# Percentage of errors introduced: 4.36% with number of deletions = 0
# Percentage of errors introduced: 3.6% with number of deletions = 0
# Percentage of errors introduced: 4.05% with number of deletions = 0
# Percentage of errors introduced: 4.18% with number of deletions = 0
# Percentage of errors introduced: 5.85% with number of deletions = 0
# Percentage of errors introduced: 3.68% with number of deletions = 0
# Percentage of errors introduced: 3.25% with number of deletions = 0
# Percentage of errors introduced: 5.54% with number of deletions = 0
# Percentage of errors introduced: 4.25% with number of deletions = 0
# Percentage of errors introduced: 5.8% with number of deletions = 0
# Percentage of errors introduced: 4.6% with number of deletions = 0
# Percentage of errors introduced: 4.14% with number of deletions = 0
# Percentage of errors introduced: 3.45% with number of deletions = 0
# Percentage of errors introduced: 5.07% with number of deletions = 0
# Percentage of errors introduced: 4.39% with number of deletions = 0
# Percentage of errors introduced: 4.6% with number of deletions = 0
# Percentage of errors introduced: 4.14% with number of deletions = 0
# Percentage of errors introduced: 3.45% with number of deletions = 0
# Percentage of errors introduced: 5.07% with number of deletions = 0
# Percentage of errors introduced: 4.39% with number of deletions = 0
# Percentage of errors introduced: 3.36% with number of deletions = 0
# Percentage of errors introduced: 2.37% with number of deletions = 0
# Percentage of errors introduced: 4.82% with number of deletions = 0
# Percentage of errors introduced: 4.58% with number of deletions = 0
# Percentage of errors introduced: 5.01% with number of deletions = 0
# Percentage of errors introduced: 3.82% with number of deletions = 0
# Percentage of errors introduced: 3.26% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 3.39% with number of deletions = 0
# Percentage of errors introduced: 4.21% with number of deletions = 0
# Percentage of errors introduced: 6.31% with number of deletions = 0
# Percentage of errors introduced: 6.25% with number of deletions = 0
# Percentage of errors introduced: 3.89% with number of deletions = 0
# Percentage of errors introduced: 3.25% with number of deletions = 0
# Percentage of errors introduced: 5.16% with number of deletions = 0
# Percentage of errors introduced: 3.12% with number of deletions = 0
# Percentage of errors introduced: 2.39% with number of deletions = 0
# Percentage of errors introduced: 5.01% with number of deletions = 0
# Percentage of errors introduced: 4.35% with number of deletions = 0
# Percentage of errors introduced: 4.69% with number of deletions = 0
# Percentage of errors introduced: 4.2% with number of deletions = 0
# Percentage of errors introduced: 4.15% with number of deletions = 0
# Percentage of errors introduced: 5.24% with number of deletions = 0
# Percentage of errors introduced: 3.55% with number of deletions = 0
# Percentage of errors introduced: 5.08% with number of deletions = 0
# Percentage of errors introduced: 4.62% with number of deletions = 0
# Percentage of errors introduced: 5.44% with number of deletions = 0
# Percentage of errors introduced: 5.19% with number of deletions = 0
# Percentage of errors introduced: 4.13% with number of deletions = 0
# Percentage of errors introduced: 5.66% with number of deletions = 0
# Percentage of errors introduced: 5.37% with number of deletions = 0
# Percentage of errors introduced: 3.57% with number of deletions = 0
# Percentage of errors introduced: 3.56% with number of deletions = 0
# Percentage of errors introduced: 5.94% with number of deletions = 0
# Percentage of errors introduced: 3.48% with number of deletions = 0
# Percentage of errors introduced: 4.85% with number of deletions = 0
# Percentage of errors introduced: 4.74% with number of deletions = 0
# Percentage of errors introduced: 4.55% with number of deletions = 0
# Percentage of errors introduced: 3.21% with number of deletions = 0
# Percentage of errors introduced: 3.85% with number of deletions = 0
# Percentage of errors introduced: 3.23% with number of deletions = 0
# Percentage of errors introduced: 5.25% with number of deletions = 0
# Percentage of errors introduced: 4.43% with number of deletions = 0
# Percentage of errors introduced: 3.39% with number of deletions = 0
# Percentage of errors introduced: 2.5% with number of deletions = 0
# Percentage of errors introduced: 3.85% with number of deletions = 0
# Percentage of errors introduced: 3.81% with number of deletions = 0
# Percentage of errors introduced: 4.55% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 3.45% with number of deletions = 0
# Percentage of errors introduced: 4.63% with number of deletions = 0
# Percentage of errors introduced: 3.78% with number of deletions = 0
# Percentage of errors introduced: 5.16% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 3.46% with number of deletions = 0
# Percentage of errors introduced: 3.24% with number of deletions = 0
# Percentage of errors introduced: 3.47% with number of deletions = 0
# Percentage of errors introduced: 3.4% with number of deletions = 0
# Percentage of errors introduced: 5.16% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 3.46% with number of deletions = 0
# Percentage of errors introduced: 3.24% with number of deletions = 0
# Percentage of errors introduced: 3.47% with number of deletions = 0
# Percentage of errors introduced: 5.76% with number of deletions = 0
# Percentage of errors introduced: 4.47% with number of deletions = 0
# Percentage of errors introduced: 5.32% with number of deletions = 0
# Percentage of errors introduced: 5.69% with number of deletions = 0
# Percentage of errors introduced: 5.36% with number of deletions = 0
# Percentage of errors introduced: 5.15% with number of deletions = 0
# Percentage of errors introduced: 6.03% with number of deletions = 0
# Percentage of errors introduced: 5.34% with number of deletions = 0
# Percentage of errors introduced: 6.57% with number of deletions = 0
# Percentage of errors introduced: 5.72% with number of deletions = 0
# Percentage of errors introduced: 6.66% with number of deletions = 0
# Percentage of errors introduced: 5.8% with number of deletions = 0
# Percentage of errors introduced: 4.01% with number of deletions = 0
# Percentage of errors introduced: 4.14% with number of deletions = 0
# Percentage of errors introduced: 5.01% with number of deletions = 0
# Percentage of errors introduced: 4.86% with number of deletions = 0
# Percentage of errors introduced: 3.66% with number of deletions = 0
# Percentage of errors introduced: 4.32% with number of deletions = 0
# Percentage of errors introduced: 4.92% with number of deletions = 0
# Percentage of errors introduced: 5.36% with number of deletions = 0
# Percentage of errors introduced: 3.57% with number of deletions = 0
# Percentage of errors introduced: 3.99% with number of deletions = 0
# Percentage of errors introduced: 4.33% with number of deletions = 0
# Percentage of errors introduced: 6.22% with number of deletions = 0
# Percentage of errors introduced: 4.36% with number of deletions = 0
# Percentage of errors introduced: 3.73% with number of deletions = 0
# Percentage of errors introduced: 3.34% with number of deletions = 0
# Percentage of errors introduced: 3.7% with number of deletions = 0
# Percentage of errors introduced: 4.41% with number of deletions = 0
# Percentage of errors introduced: 4.89% with number of deletions = 0
# Percentage of errors introduced: 3.38% with number of deletions = 0
# Percentage of errors introduced: 2.44% with number of deletions = 0
# Percentage of errors introduced: 2.84% with number of deletions = 0
# Percentage of errors introduced: 3.43% with number of deletions = 0
# Percentage of errors introduced: 3.47% with number of deletions = 0
# Percentage of errors introduced: 3.84% with number of deletions = 0
# Percentage of errors introduced: 5.2% with number of deletions = 0
# Percentage of errors introduced: 5.43% with number of deletions = 0
# Percentage of errors introduced: 3.14% with number of deletions = 0
# Percentage of errors introduced: 4.83% with number of deletions = 0
# Percentage of errors introduced: 5.04% with number of deletions = 0
# Percentage of errors introduced: 4.11% with number of deletions = 0
# Percentage of errors introduced: 3.83% with number of deletions = 0
# Percentage of errors introduced: 4.14% with number of deletions = 0
# Percentage of errors introduced: 4.2% with number of deletions = 0
# Percentage of errors introduced: 2.34% with number of deletions = 0
# Percentage of errors introduced: 4.11% with number of deletions = 0
# Percentage of errors introduced: 4.59% with number of deletions = 0
# Percentage of errors introduced: 2.39% with number of deletions = 0
# Percentage of errors introduced: 3.56% with number of deletions = 0
# Percentage of errors introduced: 4.32% with number of deletions = 0
# Percentage of errors introduced: 2.95% with number of deletions = 0
# Percentage of errors introduced: 5.36% with number of deletions = 0
# Percentage of errors introduced: 4.26% with number of deletions = 0
# Percentage of errors introduced: 4.47% with number of deletions = 0
# Percentage of errors introduced: 4.12% with number of deletions = 0
# Percentage of errors introduced: 1.81% with number of deletions = 0
# Percentage of errors introduced: 3.02% with number of deletions = 0
# Percentage of errors introduced: 1.5% with number of deletions = 0
# Percentage of errors introduced: 3.89% with number of deletions = 0
# Percentage of errors introduced: 2.68% with number of deletions = 0
# Percentage of errors introduced: 3.82% with number of deletions = 0
# Percentage of errors introduced: 3.52% with number of deletions = 0
# Percentage of errors introduced: 1.49% with number of deletions = 0
# Percentage of errors introduced: 3.99% with number of deletions = 0
# Percentage of errors introduced: 3.88% with number of deletions = 0
# Percentage of errors introduced: 3.66% with number of deletions = 0
# Percentage of errors introduced: 2.78% with number of deletions = 0
# Percentage of errors introduced: 4.17% with number of deletions = 0
# Percentage of errors introduced: 3.16% with number of deletions = 0
# Percentage of errors introduced: 4.43% with number of deletions = 0
# Percentage of errors introduced: 4.75% with number of deletions = 0
# Percentage of errors introduced: 4.08% with number of deletions = 0
# Percentage of errors introduced: 2.76% with number of deletions = 0
# Percentage of errors introduced: 4.4% with number of deletions = 0
# Percentage of errors introduced: 5.16% with number of deletions = 0
# Percentage of errors introduced: 1.98% with number of deletions = 0
# Percentage of errors introduced: 4.63% with number of deletions = 0
# Percentage of errors introduced: 4.12% with number of deletions = 0
# Percentage of errors introduced: 3.89% with number of deletions = 0
# Percentage of errors introduced: 3.39% with number of deletions = 0
# Percentage of errors introduced: 4.3% with number of deletions = 0
# Percentage of errors introduced: 4.01% with number of deletions = 0
# Percentage of errors introduced: 4.31% with number of deletions = 0
# Percentage of errors introduced: 2.11% with number of deletions = 0
# Percentage of errors introduced: 4.66% with number of deletions = 0
# Percentage of errors introduced: 3.66% with number of deletions = 0
# Percentage of errors introduced: 4.11% with number of deletions = 0
# Percentage of errors introduced: 2.85% with number of deletions = 0
# Percentage of errors introduced: 0.77% with number of deletions = 0
# Percentage of errors introduced: 4.0% with number of deletions = 0
# Percentage of errors introduced: 4.81% with number of deletions = 0
# Percentage of errors introduced: 5.02% with number of deletions = 0
# Percentage of errors introduced: 3.72% with number of deletions = 0
# Percentage of errors introduced: 3.84% with number of deletions = 0
# Percentage of errors introduced: 5.08% with number of deletions = 0
# Percentage of errors introduced: 4.27% with number of deletions = 0
# Percentage of errors introduced: 3.29% with number of deletions = 0
# Percentage of errors introduced: 4.16% with number of deletions = 0
# Percentage of errors introduced: 3.02% with number of deletions = 0
# Percentage of errors introduced: 4.85% with number of deletions = 0
# Percentage of errors introduced: 3.98% with number of deletions = 0
# Percentage of errors introduced: 4.24% with number of deletions = 0
# Percentage of errors introduced: 4.05% with number of deletions = 0
# Percentage of errors introduced: 6.55% with number of deletions = 0
# Percentage of errors introduced: 2.78% with number of deletions = 0
# Percentage of errors introduced: 5.26% with number of deletions = 0
# Percentage of errors introduced: 3.81% with number of deletions = 0
# Percentage of errors introduced: 4.65% with number of deletions = 0
# Percentage of errors introduced: 2.33% with number of deletions = 0
# Percentage of errors introduced: 2.73% with number of deletions = 0
# Percentage of errors introduced: 4.97% with number of deletions = 0
# Percentage of errors introduced: 4.26% with number of deletions = 0
# Percentage of errors introduced: 3.65% with number of deletions = 0
# Percentage of errors introduced: 3.41% with number of deletions = 0
# Percentage of errors introduced: 3.49% with number of deletions = 0
# Percentage of errors introduced: 4.82% with number of deletions = 0
# Percentage of errors introduced: 6.06% with number of deletions = 0
# Percentage of errors introduced: 5.49% with number of deletions = 0
# Percentage of errors introduced: 5.03% with number of deletions = 0
# Percentage of errors introduced: 4.08% with number of deletions = 0
# Percentage of errors introduced: 4.16% with number of deletions = 0
# Percentage of errors introduced: 4.02% with number of deletions = 0
# Percentage of errors introduced: 2.93% with number of deletions = 0
# Percentage of errors introduced: 4.68% with number of deletions = 0
# Percentage of errors introduced: 4.38% with number of deletions = 0
# Percentage of errors introduced: 4.88% with number of deletions = 0
# Percentage of errors introduced: 3.85% with number of deletions = 0
# Percentage of errors introduced: 4.81% with number of deletions = 0
# Percentage of errors introduced: 4.4% with number of deletions = 0
# Percentage of errors introduced: 4.34% with number of deletions = 0
# Percentage of errors introduced: 3.44% with number of deletions = 0
# Percentage of errors introduced: 3.91% with number of deletions = 0
# Percentage of errors introduced: 4.55% with number of deletions = 0
# Percentage of errors introduced: 3.97% with number of deletions = 0
# Percentage of errors introduced: 3.87% with number of deletions = 0
# Percentage of errors introduced: 4.42% with number of deletions = 0
# Percentage of errors introduced: 1.75% with number of deletions = 0
# Percentage of errors introduced: 4.29% with number of deletions = 0
# Percentage of errors introduced: 4.02% with number of deletions = 0
# Percentage of errors introduced: 3.68% with number of deletions = 0
# Percentage of errors introduced: 4.13% with number of deletions = 0
# Percentage of errors introduced: 4.74% with number of deletions = 0
# Percentage of errors introduced: 3.56% with number of deletions = 0
# Percentage of errors introduced: 2.26% with number of deletions = 0
# Percentage of errors introduced: 3.35% with number of deletions = 0
# Percentage of errors introduced: 2.33% with number of deletions = 0
# Percentage of errors introduced: 3.42% with number of deletions = 0
# Percentage of errors introduced: 3.43% with number of deletions = 0
# Percentage of errors introduced: 3.4% with number of deletions = 0
# Percentage of errors introduced: 4.98% with number of deletions = 0
# Percentage of errors introduced: 3.88% with number of deletions = 0
# Percentage of errors introduced: 2.37% with number of deletions = 0
# Percentage of errors introduced: 4.8% with number of deletions = 0
# Percentage of errors introduced: 4.86% with number of deletions = 0
# Percentage of errors introduced: 4.75% with number of deletions = 0
# Percentage of errors introduced: 3.94% with number of deletions = 0
# Percentage of errors introduced: 4.39% with number of deletions = 0
# Percentage of errors introduced: 4.01% with number of deletions = 0
# ...
# Percentage of errors introduced: 4.3% with number of deletions = 0
# Percentage of errors introduced: 2.87% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 3.75% with number of deletions = 0
# Percentage of errors introduced: 3.49% with number of deletions = 0
# Percentage of errors introduced: 3.44% with number of deletions = 0
# Percentage of errors introduced: 3.15% with number of deletions = 0
# Percentage of errors introduced: 4.62% with number of deletions = 0
# Percentage of errors introduced: 4.24% with number of deletions = 0
# Percentage of errors introduced: 4.05% with number of deletions = 0
# Percentage of errors introduced: 4.53% with number of deletions = 0
# Percentage of errors introduced: 4.03% with number of deletions = 0
# Percentage of errors introduced: 3.15% with number of deletions = 0
# Percentage of errors introduced: 5.53% with number of deletions = 0
# Percentage of errors introduced: 3.98% with number of deletions = 0
# Percentage of errors introduced: 3.17% with number of deletions = 0
# Percentage of errors introduced: 4.96% with number of deletions = 0
# Percentage of errors introduced: 2.6% with number of deletions = 0
# Percentage of errors introduced: 3.59% with number of deletions = 0
# Percentage of errors introduced: 3.48% with number of deletions = 0
# Percentage of errors introduced: 0.53% with number of deletions = 0
# Percentage of errors introduced: 3.61% with number of deletions = 0
# Percentage of errors introduced: 4.24% with number of deletions = 0
# Percentage of errors introduced: 2.52% with number of deletions = 0
# Percentage of errors introduced: 4.12% with number of deletions = 0
# Percentage of errors introduced: 3.35% with number of deletions = 0
# Percentage of errors introduced: 4.41% with number of deletions = 0
# Percentage of errors introduced: 4.36% with number of deletions = 0
# Percentage of errors introduced: 4.4% with number of deletions = 0
# Percentage of errors introduced: 2.04% with number of deletions = 0
# Percentage of errors introduced: 2.51% with number of deletions = 0
# Percentage of errors introduced: 4.1% with number of deletions = 0
# Percentage of errors introduced: 4.37% with number of deletions = 0
# Percentage of errors introduced: 3.59% with number of deletions = 0
# Percentage of errors introduced: 3.34% with number of deletions = 0
# Percentage of errors introduced: 3.72% with number of deletions = 0
# Percentage of errors introduced: 5.59% with number of deletions = 0
# Percentage of errors introduced: 3.4% with number of deletions = 0
# Percentage of errors introduced: 3.63% with number of deletions = 0
# Percentage of errors introduced: 2.86% with number of deletions = 0
# Percentage of errors introduced: 2.46% with number of deletions = 0
# Percentage of errors introduced: 4.86% with number of deletions = 0
# Percentage of errors introduced: 2.67% with number of deletions = 0
# Percentage of errors introduced: 4.69% with number of deletions = 0
# Percentage of errors introduced: 5.01% with number of deletions = 0
# Percentage of errors introduced: 3.29% with number of deletions = 0
# Percentage of errors introduced: 4.91% with number of deletions = 0
# Percentage of errors introduced: 4.42% with number of deletions = 0
# Percentage of errors introduced: 3.77% with number of deletions = 0
# Percentage of errors introduced: 3.8% with number of deletions = 0
# Percentage of errors introduced: 3.68% with number of deletions = 0
# Percentage of errors introduced: 4.35% with number of deletions = 0
# Percentage of errors introduced: 5.15% with number of deletions = 0
# Percentage of errors introduced: 3.36% with number of deletions = 0
# Percentage of errors introduced: 3.2% with number of deletions = 0
# Percentage of errors introduced: 3.52% with number of deletions = 0
# Percentage of errors introduced: 3.12% with number of deletions = 0
# Percentage of errors introduced: 4.88% with number of deletions = 0
# Percentage of errors introduced: 3.43% with number of deletions = 0
# Percentage of errors introduced: 2.82% with number of deletions = 0
# Percentage of errors introduced: 3.65% with number of deletions = 0
# Percentage of errors introduced: 5.23% with number of deletions = 0
# Percentage of errors introduced: 3.52% with number of deletions = 0
# Percentage of errors introduced: 3.12% with number of deletions = 0
# Percentage of errors introduced: 4.88% with number of deletions = 0
# Percentage of errors introduced: 3.43% with number of deletions = 0
# Percentage of errors introduced: 2.82% with number of deletions = 0
# Percentage of errors introduced: 5.49% with number of deletions = 0
# Percentage of errors introduced: 3.99% with number of deletions = 0
# Percentage of errors introduced: 4.7% with number of deletions = 0
# Percentage of errors introduced: 1.59% with number of deletions = 0
# Percentage of errors introduced: 4.64% with number of deletions = 0
# Percentage of errors introduced: 3.47% with number of deletions = 0
# Percentage of errors introduced: 2.84% with number of deletions = 0
# Percentage of errors introduced: 4.87% with number of deletions = 0
# Percentage of errors introduced: 4.76% with number of deletions = 0
# Percentage of errors introduced: 3.74% with number of deletions = 0
# Percentage of errors introduced: 5.43% with number of deletions = 0
# Percentage of errors introduced: 3.11% with number of deletions = 0
# Percentage of errors introduced: 4.19% with number of deletions = 0
# Percentage of errors introduced: 3.88% with number of deletions = 0
# Percentage of errors introduced: 4.08% with number of deletions = 0
# Percentage of errors introduced: 4.93% with number of deletions = 0
# Percentage of errors introduced: 2.33% with number of deletions = 0
# Percentage of errors introduced: 3.71% with number of deletions = 0
# Percentage of errors introduced: 4.75% with number of deletions = 0
# Percentage of errors introduced: 4.66% with number of deletions = 0
# Percentage of errors introduced: 4.34% with number of deletions = 0
# Percentage of errors introduced: 5.26% with number of deletions = 0
# Percentage of errors introduced: 4.08% with number of deletions = 0
# Percentage of errors introduced: 4.71% with number of deletions = 0
# Percentage of errors introduced: 3.17% with number of deletions = 0
# Percentage of errors introduced: 3.89% with number of deletions = 0
# Percentage of errors introduced: 4.4% with number of deletions = 0
# Percentage of errors introduced: 4.16% with number of deletions = 0
# Percentage of errors introduced: 5.44% with number of deletions = 0
# Percentage of errors introduced: 3.7% with number of deletions = 0
# Percentage of errors introduced: 4.94% with number of deletions = 0
# Percentage of errors introduced: 4.62% with number of deletions = 0
# Percentage of errors introduced: 4.64% with number of deletions = 0
# Percentage of errors introduced: 4.36% with number of deletions = 0
# Percentage of errors introduced: 5.24% with number of deletions = 0
# Percentage of errors introduced: 4.77% with number of deletions = 0
# Percentage of errors introduced: 5.05% with number of deletions = 0
# Percentage of errors introduced: 4.44% with number of deletions = 0
# Percentage of errors introduced: 4.63% with number of deletions = 0
# Percentage of errors introduced: 3.52% with number of deletions = 0
# Percentage of errors introduced: 4.68% with number of deletions = 0
# Percentage of errors introduced: 3.99% with number of deletions = 0
# Percentage of errors introduced: 4.17% with number of deletions = 0
# Percentage of errors introduced: 3.39% with number of deletions = 0
# Percentage of errors introduced: 4.61% with number of deletions = 0
# Percentage of errors introduced: 5.58% with number of deletions = 0
# Percentage of errors introduced: 4.77% with number of deletions = 0
# Percentage of errors introduced: 5.58% with number of deletions = 0
# Percentage of errors introduced: 4.53% with number of deletions = 0
# Percentage of errors introduced: 4.96% with number of deletions = 0
# Percentage of errors introduced: 4.96% with number of deletions = 0
# Percentage of errors introduced: 3.58% with number of deletions = 0
# Percentage of errors introduced: 2.78% with number of deletions = 0
# Percentage of errors introduced: 2.99% with number of deletions = 0
# Percentage of errors introduced: 3.16% with number of deletions = 0
# Percentage of errors introduced: 2.78% with number of deletions = 0
# Percentage of errors introduced: 4.48% with number of deletions = 0
# Percentage of errors introduced: 4.23% with number of deletions = 0
# Percentage of errors introduced: 0.48% with number of deletions = 0
# Percentage of errors introduced: 3.85% with number of deletions = 0
# Percentage of errors introduced: 2.75% with number of deletions = 0
# Percentage of errors introduced: 5.06% with number of deletions = 0
# Percentage of errors introduced: 3.99% with number of deletions = 0
# Percentage of errors introduced: 3.48% with number of deletions = 0
# Percentage of errors introduced: 5.93% with number of deletions = 0
# Percentage of errors introduced: 5.61% with number of deletions = 0
# Percentage of errors introduced: 5.1% with number of deletions = 0
# Percentage of errors introduced: 4.63% with number of deletions = 0
# Percentage of errors introduced: 3.34% with number of deletions = 0
# Percentage of errors introduced: 5.36% with number of deletions = 0
# Percentage of errors introduced: 5.36% with number of deletions = 0
# Percentage of errors introduced: 2.52% with number of deletions = 0
# Percentage of errors introduced: 5.2% with number of deletions = 0
# Percentage of errors introduced: 3.59% with number of deletions = 0
# Percentage of errors introduced: 3.54% with number of deletions = 0
# Percentage of errors introduced: 3.27% with number of deletions = 0
# Percentage of errors introduced: 3.29% with number of deletions = 0
# Percentage of errors introduced: 5.05% with number of deletions = 0
# Percentage of errors introduced: 4.61% with number of deletions = 0
# Percentage of errors introduced: 4.4% with number of deletions = 0
# Percentage of errors introduced: 3.44% with number of deletions = 0
# Percentage of errors introduced: 3.48% with number of deletions = 0
# Percentage of errors introduced: 3.66% with number of deletions = 0
# Percentage of errors introduced: 4.27% with number of deletions = 0
# Percentage of errors introduced: 4.09% with number of deletions = 0
# Percentage of errors introduced: 4.65% with number of deletions = 0
# Percentage of errors introduced: 5.05% with number of deletions = 0
# Percentage of errors introduced: 4.01% with number of deletions = 0
# Percentage of errors introduced: 3.23% with number of deletions = 0
# Percentage of errors introduced: 3.86% with number of deletions = 0
# Percentage of errors introduced: 3.37% with number of deletions = 0
# Percentage of errors introduced: 2.97% with number of deletions = 0
# Percentage of errors introduced: 5.65% with number of deletions = 0
# Percentage of errors introduced: 3.85% with number of deletions = 0
# Percentage of errors introduced: 3.09% with number of deletions = 0
# Percentage of errors introduced: 3.7% with number of deletions = 0
# Percentage of errors introduced: 3.59% with number of deletions = 0
# Percentage of errors introduced: 3.61% with number of deletions = 0
# Percentage of errors introduced: 3.98% with number of deletions = 0
# Percentage of errors introduced: 3.71% with number of deletions = 0
# Percentage of errors introduced: 5.03% with number of deletions = 0
# Percentage of errors introduced: 4.77% with number of deletions = 0
# Percentage of errors introduced: 4.84% with number of deletions = 0
# Percentage of errors introduced: 4.1% with number of deletions = 0
# Percentage of errors introduced: 3.07% with number of deletions = 0
# Percentage of errors introduced: 4.07% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 4.47% with number of deletions = 0
# Percentage of errors introduced: 4.03% with number of deletions = 0
# Percentage of errors introduced: 3.31% with number of deletions = 0
# Percentage of errors introduced: 5.11% with number of deletions = 0
# Percentage of errors introduced: 4.38% with number of deletions = 0
# Percentage of errors introduced: 3.59% with number of deletions = 0
# Percentage of errors introduced: 3.08% with number of deletions = 0
# Percentage of errors introduced: 5.81% with number of deletions = 0
# Percentage of errors introduced: 5.7% with number of deletions = 0
# Percentage of errors introduced: 4.73% with number of deletions = 0
# Percentage of errors introduced: 4.31% with number of deletions = 0
# Percentage of errors introduced: 4.1% with number of deletions = 0
# Percentage of errors introduced: 4.18% with number of deletions = 0
# Percentage of errors introduced: 5.46% with number of deletions = 0
# Percentage of errors introduced: 4.85% with number of deletions = 0
# Percentage of errors introduced: 3.92% with number of deletions = 0
# Percentage of errors introduced: 2.87% with number of deletions = 0
# Percentage of errors introduced: 3.0% with number of deletions = 0
# Percentage of errors introduced: 3.88% with number of deletions = 0
# Percentage of errors introduced: 3.7% with number of deletions = 0
# Percentage of errors introduced: 4.3% with number of deletions = 0
# Percentage of errors introduced: 3.64% with number of deletions = 0
# Percentage of errors introduced: 3.82% with number of deletions = 0
# Percentage of errors introduced: 3.26% with number of deletions = 0
# Percentage of errors introduced: 3.3% with number of deletions = 0
# Percentage of errors introduced: 3.39% with number of deletions = 0
# Percentage of errors introduced: 5.51% with number of deletions = 0
# Percentage of errors introduced: 4.87% with number of deletions = 0
# Percentage of errors introduced: 3.86% with number of deletions = 0
# Percentage of errors introduced: 4.76% with number of deletions = 0
# Percentage of errors introduced: 6.56% with number of deletions = 0
# Percentage of errors introduced: 5.5% with number of deletions = 0
# Percentage of errors introduced: 4.73% with number of deletions = 0
# Percentage of errors introduced: 4.85% with number of deletions = 0
# Percentage of errors introduced: 5.04% with number of deletions = 0
# Percentage of errors introduced: 4.0% with number of deletions = 0
# Percentage of errors introduced: 5.1% with number of deletions = 0
# Percentage of errors introduced: 6.35% with number of deletions = 0
# Percentage of errors introduced: 5.26% with number of deletions = 0
# Percentage of errors introduced: 4.81% with number of deletions = 0
# Percentage of errors introduced: 4.64% with number of deletions = 0
# Percentage of errors introduced: 5.8% with number of deletions = 0
# Percentage of errors introduced: 4.95% with number of deletions = 0
# Percentage of errors introduced: 3.86% with number of deletions = 0
# Percentage of errors introduced: 3.73% with number of deletions = 0
# Percentage of errors introduced: 4.34% with number of deletions = 0
# Percentage of errors introduced: 2.45% with number of deletions = 0
# Percentage of errors introduced: 3.59% with number of deletions = 0
# Percentage of errors introduced: 3.79% with number of deletions = 0
# Percentage of errors introduced: 5.48% with number of deletions = 0
# Percentage of errors introduced: 3.04% with number of deletions = 0
# Percentage of errors introduced: 3.55% with number of deletions = 0
# Percentage of errors introduced: 4.72% with number of deletions = 0
# Percentage of errors introduced: 4.14% with number of deletions = 0
# Percentage of errors introduced: 2.78% with number of deletions = 0
# Percentage of errors introduced: 3.8% with number of deletions = 0
# Percentage of errors introduced: 3.59% with number of deletions = 0
# Percentage of errors introduced: 4.85% with number of deletions = 0
# Percentage of errors introduced: 3.47% with number of deletions = 0
# Percentage of errors introduced: 4.6% with number of deletions = 0
# Percentage of errors introduced: 3.66% with number of deletions = 0
